# %%
import sys
import matplotlib.pyplot as plt

# %%
print(f"Notebook working")

X = ['A', 'B', 'C', 'D', 'E']
Y = [1, 2, 3, 4, 5]

plt.plot(X, Y)
plt.title("This is a line graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
# Out:
# Notebook working
